# %% [markdown]
# <a href="https://colab.research.google.com/github/nattyix/ML-LAB/blob/main/MLLab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.read_csv("Iris.csv")
x = data.iloc[:,:-1]
y = data.iloc[:,-1]
k_values = [1, 3, 5]

# %%
for k in k_values:
  correct = 0;
  for i in range(len(x)):
    x_train = x.drop(i)
    y_train = y.drop(i)
    x_test = x.iloc[[i]]
    y_test = y.iloc[i]

    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(x_train,y_train)

    prediction = model.predict(x_test)[0]
    if prediction == y_test:
      correct+=1
  accuracy = (correct/len(x))*100
  print(f"LOOCV accuracy for k={k}: {accuracy:.2f}%")
# Out:
# LOOCV accuracy for k=1: 100.00%
# LOOCV accuracy for k=3: 100.00%
# LOOCV accuracy for k=5: 100.00%
