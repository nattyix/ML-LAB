# %% [markdown]
# <a href="https://colab.research.google.com/github/nattyix/ML-LAB/blob/main/MLLab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
import numpy as np

# %%
data = pd.read_csv("Iris.csv")
print(data.head)
# Out:
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]>

# %%
x = data.iloc[:,0:4].values
y = data.iloc[:,4].values
scaler = StandardScaler()
x = scaler.fit_transform(x)

pca = PCA(n_components=2)
x_pca = pca.fit_transform(x)
x_pca
# Out:
# array([[-2.5010211 ,  0.45186775],
#        [-2.27994463, -0.69669785],
#        [-2.5594354 , -0.3834877 ],
#        [-2.47606034, -0.63624267],
#        [-2.57940725,  0.61105046],
#        [-2.41608653,  1.45442473],
#        [-2.67128549, -0.01125485],
#        [-2.37428299,  0.19666591],
#        [-2.43743351, -1.1596121 ],
#        [-2.21120456, -0.481981  ],
#        [-2.28528115,  1.02936615],
#        [-2.41535954,  0.09918841],
#        [-2.20214837, -0.74540999],
#        [-2.60291405, -1.01131174],
#        [-2.28337369,  1.85118404],
#        [-2.50047816,  2.64889214],
#        [-2.40871586,  1.44192887],
#        [-2.28383758,  0.45540953],
#        [-1.99504834,  1.40079155],
#        [-2.42525831,  1.08758281],
#        [-1.89068452,  0.41078364],
#        [-2.33295341,  0.87864626],
#        [-2.73354511,  0.39599747],
#        [-1.97380689,  0.04904379],
#        [-2.14940814,  0.11298753],
#        [-1.84401842, -0.63330002],
#        [-2.09825851,  0.20432127],
#        [-2.06005835,  0.5121937 ],
#        [-2.01381891,  0.29935191],
#        [-2.11462698, -0.36677182],
#        [-1.97236333, -0.52491284],
#        [-1.81673393,  0.40568159],
#        [-2.39670423,  1.76935482],
#        [-2.29576981,  2.12823113],
#        [-1.89181702, -0.4767725 ],
#        [-1.98293105, -0.22729774],
#        [-1.82345599,  0.6596866 ],
#        [-1.85349052, -0.47614748],
#        [-2.15421233, -0.94770557],
#        [-1.9027327 ,  0.25433667],
#        [-2.08602527,  0.40550057],
#        [-1.58587429, -2.36154932],
#        [-2.23661813, -0.52816574],
#        [-1.94782888,  0.41721628],
#        [-1.97271093,  1.10757891],
#        [-1.78055683, -0.73853477],
#        [-2.04702982,  1.09690489],
#        [-2.01398214, -0.42141938],
#        [-1.86254636,  0.98627919],
#        [-1.80424801, -0.00763395],
#        [ 0.62853528,  0.92529641],
#        [ 0.19832531,  0.61208767],
#        [ 0.72468585,  0.67274977],
#        [ 0.09360327, -1.74919418],
#        [ 0.59969163, -0.16999947],
#        [ 0.0773031 , -0.58151906],
#        [ 0.19929459,  0.77887253],
#        [-0.5314839 , -1.87090915],
#        [ 0.64677399,  0.091191  ],
#        [-0.31825205, -1.06723973],
#        [-0.09682763, -2.6492994 ],
#        [ 0.04604695, -0.07064549],
#        [ 0.58900797, -1.70165296],
#        [ 0.43027017, -0.15908979],
#        [-0.23681519, -0.45456674],
#        [ 0.59884904,  0.55496594],
#        [ 0.02159156, -0.21152473],
#        [ 0.22693743, -0.75215594],
#        [ 0.9575793 , -1.57991067],
#        [ 0.19394779, -1.27984729],
#        [ 0.22725843,  0.37211743],
#        [ 0.36619835, -0.3926546 ],
#        [ 1.00431371, -0.88522612],
#        [ 0.62477908, -0.36635963],
#        [ 0.62584361, -0.01857401],
#        [ 0.73062369,  0.29669222],
#        [ 1.13553535, -0.00501056],
#        [ 1.01864872,  0.37029417],
#        [ 0.49258851, -0.21436237],
#        [ 0.18452331, -1.03219437],
#        [ 0.30520798, -1.54160956],
#        [ 0.28469352, -1.54509812],
#        [ 0.35199002, -0.75642464],
#        [ 0.88971358, -0.60984575],
#        [ 0.12608207, -0.30978237],
#        [ 0.24824753,  0.83386219],
#        [ 0.96700445,  0.57043177],
#        [ 1.16300422, -1.31929199],
#        [ 0.16949275, -0.22172885],
#        [ 0.42001352, -1.32298747],
#        [ 0.49919497, -1.0986383 ],
#        [ 0.68794035,  0.05240006],
#        [ 0.5797889 , -0.95999757],
#        [ 0.0579223 , -2.02175827],
#        [ 0.47969741, -0.84484162],
#        [ 0.35494547, -0.16556969],
#        [ 0.43447487, -0.37471459],
#        [ 0.79421163, -0.11578995],
#        [-0.04884362, -1.56209691],
#        [ 0.50626531, -0.5871397 ],
#        [ 1.19418614,  0.83609917],
#        [ 0.99420409, -0.70810339],
#        [ 1.88858294,  0.61279028],
#        [ 1.36636839, -0.01547635],
#        [ 1.50443843,  0.30348679],
#        [ 2.47361046,  0.89431299],
#        [ 0.4272413 , -1.60698447],
#        [ 2.27784271,  0.5212741 ],
#        [ 2.01477844, -0.64043828],
#        [ 1.70680224,  1.92876575],
#        [ 1.21455391,  0.697565  ],
#        [ 1.56494457, -0.39260292],
#        [ 1.69497533,  0.44707445],
#        [ 1.18499368, -1.17901056],
#        [ 1.09353171, -0.49604173],
#        [ 1.28227709,  0.65499662],
#        [ 1.55787456,  0.29489617],
#        [ 2.18890952,  2.62633973],
#        [ 3.06931171,  0.12170304],
#        [ 1.65011115, -1.65280859],
#        [ 1.79298573,  0.92584531],
#        [ 0.99091177, -0.60398491],
#        [ 2.920326  ,  0.53384907],
#        [ 1.52235648, -0.45589431],
#        [ 1.65186532,  1.03402415],
#        [ 2.14493589,  1.09098935],
#        [ 1.39790487, -0.30061683],
#        [ 1.24772828,  0.070991  ],
#        [ 1.81524408, -0.1686172 ],
#        [ 2.26296577,  0.66572244],
#        [ 2.63458747,  0.36032276],
#        [ 2.39336517,  2.72017356],
#        [ 1.86634608, -0.16778384],
#        [ 1.64993752, -0.23706388],
#        [ 1.83720211, -0.73908527],
#        [ 2.75315995,  0.93308257],
#        [ 1.45419044,  1.03816505],
#        [ 1.69667193,  0.45762066],
#        [ 1.29223457,  0.01858196],
#        [ 2.00260426,  0.70935984],
#        [ 1.95649117,  0.61495422],
#        [ 1.92828538,  0.69868582],
#        [ 1.51799964, -0.69956145],
#        [ 2.09066792,  0.88702705],
#        [ 1.90737534,  1.03819095],
#        [ 1.95396273,  0.39185509],
#        [ 1.98299077, -0.86611207],
#        [ 1.85404522,  0.29026401],
#        [ 1.47818228,  0.98226745],
#        [ 1.46990071, -0.01903948]])

# %%
print("Explained Variance:", pca.explained_variance_ratio_)
# Out:
# Explained Variance: [0.70308855 0.22873259]

# %%
plt.figure(figsize=(8,6))
le = LabelEncoder()
y_encoded = le.fit_transform(y)
for i in np.unique(y_encoded):
  plt.scatter(x_pca[y_encoded==i,0], x_pca[y_encoded==i,1], label=le.inverse_transform([i])[0])
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend()
plt.show()
print(pca.components_)
# Out:
# [[ 0.55318314  0.51774664 -0.28847469  0.58541369]
#  [ 0.00902118  0.42093567  0.90471285  0.06501105]]
